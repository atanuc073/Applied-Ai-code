# %%
# Importing libraries needed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data
train=pd.read_csv("train_v9rqX0R.csv")
test=pd.read_csv("test_AbJTz2l.csv")

# %%
# Vizualizing Dataset

print(train.shape)
print(test.shape)
train.head()
# Out:
# (8523, 12)
# (5681, 11)
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# List of unique products
len(train["Item_Identifier"].unique())
# Out:
# 1559

# %%
#Data Description
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# Finding number of null values in each column
train.isna().sum()
#item_weight and outlet_size has null values
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Categories columns
cat_cols=train.select_dtypes("object").columns
numerical_cols=train.select_dtypes("number").columns

# %%
#get all the Unique values of Categorical column
for i in cat_cols:
    print(i)
    print(train[i].unique(),len(train[i].unique()))
    print("---------------------------------")
# Out:
# Item_Identifier
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05'] 1559
# ---------------------------------
# Item_Fat_Content
# ['Low Fat' 'Regular' 'low fat' 'LF' 'reg'] 5
# ---------------------------------
# Item_Type
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood'] 16
# ---------------------------------
# Outlet_Identifier
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019'] 10
# ---------------------------------
# Outlet_Size
# ['Medium' nan 'High' 'Small'] 4
# ---------------------------------
# Outlet_Location_Type
# ['Tier 1' 'Tier 3' 'Tier 2'] 3
# ---------------------------------
# Outlet_Type
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3'] 4
# ---------------------------------

# %% [markdown]
# ['Low Fat', 'Regular', 'low fat', 'LF', 'reg'] - LF, low fat and Low Fat are same while reg and Regular are same

# %%
train.replace({'reg':'Regular','low fat':'Low Fat','LF':'Low Fat'})
test.replace({'reg':'Regular','low fat':'Low Fat','LF':'Low Fat'})
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300          Regular         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
train.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train_data=pd.DataFrame()
for item in list(set(train["Item_Identifier"])):
    temp=train.loc[train["Item_Identifier"]==item].copy()
    
    temp["Item_Weight"].fillna(temp["Item_Weight"].mean(),inplace=True)
    train_data=train_data.append(temp)
    
print(train_data.shape)
train_data
# Out:
# (8523, 12)
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4815           FDD33        12.85          Low Fat         0.108633
# 5326           FDD33        12.85          Low Fat         0.108412
# 5494           FDD33        12.85          Low Fat         0.000000
# 7350           FDD33        12.85          Low Fat         0.108103
# 3817           FDG32        19.85               LF         0.176991
# ...              ...          ...              ...              ...
# 2383           FDH14        17.10          Regular         0.046881
# 3578           FDH14        17.10          Regular         0.046903
# 6501           FDH14        17.10          Regular         0.047073
# 7143           FDH14        17.10          Regular         0.081956
# 7689           FDH14        17.10          Regular         0.078348
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4815  Fruits and Vegetables  233.8642            OUT018
# ...

# %%
test_data=pd.DataFrame()
for item in list(set(test["Item_Identifier"])):
    temp=test.loc[test["Item_Identifier"]==item].copy()
    temp["Item_Weight"].fillna(temp["Item_Weight"].mean(),inplace=True)
    test_data=test_data.append(temp)
print(test_data.shape)
# Out:
# (5681, 11)

# %%
train_data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     4
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test_data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                    20
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
products=list(train_data[train_data["Item_Weight"].isnull()]["Item_Identifier"])
products
# Out:
# ['FDQ60', 'FDK57', 'FDE52', 'FDN52']

# %%
test_products=list(test_data[test_data["Item_Weight"].isnull()]["Item_Identifier"])
len(test_products)
# Out:
# 20

# %%
product_weight_test=[]
for item in test_products:
    product_weight_test.append(train[train["Item_Identifier"]==item].iloc[0]["Item_Weight"])
dictionary=dict(zip(test_products,product_weight_test))

# %%
dictionary
# Out:
# {'FDT21': 7.42,
#  'FDI45': 13.1,
#  'FDG09': 20.6,
#  'FDF22': 6.865,
#  'FDG57': 14.7,
#  'FDO22': 13.5,
#  'FDG50': 7.405,
#  'DRN47': 12.1,
#  'FDJ09': 15.0,
#  'FDY57': 20.2,
#  'FDF04': 17.5,
#  'FDP28': 13.65,
#  'NCJ30': 5.82,
#  'FDF05': 17.5,
#  'FDL58': 5.78,
#  'FDH58': 12.3}

# %%
product_weight=[]
for item in products:
    product_weight.append(test[test["Item_Identifier"]==item].iloc[0]["Item_Weight"])
dictionary1=dict(zip(products,product_weight))

# %%
dictionary1
# Out:
# {'FDQ60': 6.195, 'FDK57': 10.195, 'FDE52': 10.395, 'FDN52': 9.395}

# %%
train_data[train_data["Item_Identifier"]=="FDN52"]
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 927           FDN52          NaN          Regular         0.130933
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 927  Frozen Foods   86.9198            OUT027                       1985
#
#     Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 927      Medium               Tier 3  Supermarket Type3          1569.9564

# %%
train_data.loc[train_data["Item_Weight"].isnull(),"Item_Weight"]=train_data["Item_Identifier"].map(dictionary1)

# %%
test_data.loc[test_data["Item_Weight"].isnull(),"Item_Weight"]=test_data["Item_Identifier"].map(dictionary)

# %%
test_data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
train_data[train_data["Outlet_Size"].isnull()]["Outlet_Type"].unique()

# only two type of Outlet size have null value in Outlet_size
# Out:
# array(['Supermarket Type1', 'Grocery Store'], dtype=object)

# %%
# checking which Outlet_size is more in Supermarket Type1
train_data[train_data["Outlet_Type"]=='Supermarket Type1'].groupby("Outlet_Size").count()
# Out:
#              Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# Outlet_Size
# High                     932          932               932              932
# Medium                   930          930               930              930
# Small                   1860         1860              1860             1860
#
#              Item_Type  Item_MRP  Outlet_Identifier  \
# Outlet_Size
# High               932       932                932
# Medium             930       930                930
# Small             1860      1860               1860
#
#              Outlet_Establishment_Year  Outlet_Location_Type  Outlet_Type  \
# Outlet_Size
# High                               932                   932          932
# Medium                             930                   930          930
# Small                             1860                  1860         1860
#
#              Item_Outlet_Sales
# Outlet_Size
# High                       932
# ...

# %%
# checking which Outlet_size is more in Grocery Store
train_data[train_data["Outlet_Type"]=='Grocery Store'].groupby("Outlet_Size").count()
# Out:
#              Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# Outlet_Size
# Small                    528          528               528              528
#
#              Item_Type  Item_MRP  Outlet_Identifier  \
# Outlet_Size
# Small              528       528                528
#
#              Outlet_Establishment_Year  Outlet_Location_Type  Outlet_Type  \
# Outlet_Size
# Small                              528                   528          528
#
#              Item_Outlet_Sales
# Outlet_Size
# Small                      528
